# %%
#Programa: Respuesta bool string

respuesta_usuario = "False"

es_verdad = bool(respuesta_usuario)

print("El valor es: ",es_verdad)

#Nos dara True por que el "False" no esta vacio
#Forma correcta de resolver el ejercicio

texto_vacio = ""

print("El valor es: ",bool(texto_vacio))
# Out:
# El valor es:  True
# False
